# %% [markdown]
# ### Import packages

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import os
import time
import pathlib
import glob
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


from util import config
from util import mapping
from util import get_data
from util import clean_data

# %% [markdown]
# # Get Data from RideWithGPS
#
# The [Ride With GPS API](https://ridewithgps.com/api?lang=en) allows the user to query in multiple ways.  Here, we use two.
#
# **Route Search**
#
# We can enter a variety of search parameters and return some ride summary information, including the Ride ID. Here, we enter a location on which to centre the search ('Shokan, NY') and a radius around that to limit the search (25 miles).
#
# **Trip Details**
#
# Given the Ride IDs, we can request more detailed information - specifically, the Latitude/Longitude/Elevation/Time breadcrumbs along the ride.

# %%
# Get data and save to disk
# Note: can only return 300 results at a time

print('Requesting all ride data in search radius')
DATA = get_data.search_ridewithgps('Shokan, NY', 25)
routes, trips = get_data.parse_ridewithgps_search_results(DATA)
# Out:
# Requesting all ride data in search radius
# 300 of 42216 results collected
# 600 of 42216 results collected
# 900 of 42216 results collected
# 1200 of 42216 results collected
# 1500 of 42216 results collected
# 1800 of 42216 results collected
# 2100 of 42216 results collected
# 2400 of 42216 results collected
# 2700 of 42216 results collected
# 3000 of 42216 results collected
# 3300 of 42216 results collected
# 3600 of 42216 results collected
# 3900 of 42216 results collected
# 4200 of 42216 results collected
# 4500 of 42216 results collected
# 4800 of 42216 results collected
# 5100 of 42216 results collected
# 5400 of 42216 results collected
# 5700 of 42216 results collected
# 6000 of 42216 results collected
# 6300 of 42216 results collected
# 6600 of 42216 results collected
# 6900 of 42216 results collected
# 7200 of 42216 results collected
# 7500 of 42216 results collected
# 7800 of 42216 results collected
# 8100 of 42216 results collected
# 8400 of 42216 results collected
# 8700 of 42216 results collected
# 9000 of 42216 results collected
# 9300 of 42216 results collected
# 9600 of 42216 results collected
# 9900 of 42216 results collected
# 10200 of 42216 results collected
# 10500 of 42216 results collected
# 10800 of 42216 results collected
# 11100 of 42216 results collected
# 11400 of 42216 results collected
# 11700 of 42216 results collected
# 12000 of 42216 results collected
# 12300 of 42216 results collected
# 12600 of 42216 results collected
# 12900 of 42216 results collected
# 13200 of 42216 results collected
# 13500 of 42216 results collected
# 13800 of 42216 results collected
# 14100 of 42216 results collected
# 14400 of 42216 results collected
# 14700 of 42216 results collected
# 15000 of 42216 results collected
# 15300 of 42216 results collected
# 15600 of 42216 results collected
# 15900 of 42216 results collected
# 16200 of 42216 results collected
# 16500 of 42216 results collected
# 16800 of 42216 results collected
# 17100 of 42216 results collected
# 17400 of 42216 results collected
# 17700 of 42216 results collected
# 18000 of 42216 results collected
# 18300 of 42216 results collected
# 18600 of 42216 results collected
# 18900 of 42216 results collected
# 19200 of 42216 results collected
# 19500 of 42216 results collected
# 19800 of 42216 results collected
# 20100 of 42216 results collected
# 20400 of 42216 results collected
# 20700 of 42216 results collected
# 21000 of 42216 results collected
# 21300 of 42216 results collected
# 21600 of 42216 results collected
# 21900 of 42216 results collected
# 22200 of 42216 results collected
# 22500 of 42216 results collected
# 22800 of 42216 results collected
# 23100 of 42216 results collected
# 23400 of 42216 results collected
# 23700 of 42216 results collected
# 24000 of 42216 results collected
# 24300 of 42216 results collected
# 24600 of 42216 results collected
# 24900 of 42216 results collected
# 25200 of 42216 results collected
# 25500 of 42216 results collected
# 25800 of 42216 results collected
# 26100 of 42216 results collected
# 26400 of 42216 results collected
# 26700 of 42216 results collected
# 27000 of 42216 results collected
# 27300 of 42216 results collected
# 27600 of 42216 results collected
# 27900 of 42216 results collected
# 28200 of 42216 results collected
# 28500 of 42216 results collected
# 28800 of 42216 results collected
# 29100 of 42216 results collected
# 29400 of 42216 results collected
# 29700 of 42216 results collected
# 30000 of 42216 results collected
# 30300 of 42216 results collected
# 30600 of 42216 results collected
# 30900 of 42216 results collected
# 31200 of 42216 results collected
# 31500 of 42216 results collected
# 31800 of 42216 results collected
# 32100 of 42216 results collected
# 32400 of 42216 results collected
# 32700 of 42216 results collected
# 33000 of 42216 results collected
# 33300 of 42216 results collected
# 33600 of 42216 results collected
# 33900 of 42216 results collected
# 34200 of 42216 results collected
# 34500 of 42216 results collected
# 34800 of 42216 results collected
# 35100 of 42216 results collected
# 35400 of 42216 results collected
# 35700 of 42216 results collected
# 36000 of 42216 results collected
# 36300 of 42216 results collected
# 36600 of 42216 results collected
# 36900 of 42216 results collected
# 37200 of 42216 results collected
# 37500 of 42216 results collected
# 37800 of 42216 results collected
# 38100 of 42216 results collected
# 38400 of 42216 results collected
# 38700 of 42216 results collected
# 39000 of 42216 results collected
# 39300 of 42216 results collected
# 39600 of 42216 results collected
# 39900 of 42216 results collected
# 40200 of 42216 results collected
# 40500 of 42216 results collected
# 40800 of 42216 results collected
# 41100 of 42216 results collected
# 41400 of 42216 results collected
# 41700 of 42216 results collected
# 42000 of 42216 results collected
# 42190 of 42216 results collected
# Requesting data for each trip
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-772f6a32433e> in <module>
#       7 print('Requesting data for each trip')
#       8 for i, r in trips.iterrows():
# ----> 9     _ = get_data.ridewithgps_api_ride(r.id)
#      10     time.sleep(1.5)
#
# AttributeError: module 'util.get_data' has no attribute 'ridewithgps_api_ride'

# %% [markdown]
# ### Do some preliminary culling and cleaning of the data
#
# * Convert units from SI to miles and feet
# * Filter the data to remove trips that are
#     * uninterestingly short
#     * suspiciously long to be humanly possible
#     * likely to be mountain bike routes (e.g. very steep or lots of laps)
#
# Note: I am only interested in 'trip' data - that is, rides that users have actually been on and recorded on their GPS units.  'Routes', which are planned on the RideWithGPS interface, are often unrealistic (or highly duplicated) - restricting to 'trips' means that all of the rides returned will have literally been road-tested!

# %%
trips = pd.read_feather(
    os.path.join(config.RAW_DATA_PATH, 'ridewgps_trips.feather')
)
clean_data.convert_ride_data_from_SI(trips)
# Remove some of the trips e.g. if don't seem plausible for a human to achieve!
trips = clean_data.filter_trips(trips)

# Extract interesting columns
useful_cols = ['id', 'user_id', 'distance', 'elevation_gain', 
               'elevation_loss', 'avg_slope', 'avg_speed', 'max_speed',
               'duration', 'moving_time']
trips = trips[useful_cols]
trips.rename(columns={'id': 'rte_id'}, inplace=True) # Distinguish from other ID keys

# Save cleaned data
pathlib.Path(config.CLEAN_DATA_PATH).mkdir(parents=True, exist_ok=True)
trips.to_feather(
    os.path.join(config.CLEAN_DATA_PATH, 'ridewgps_trips.feather')
)

print('Double checking for nulls')
print(trips.isna().sum())

print('\n\n{} unique trips'.format(trips.shape[0]))
trips.head()
# Out:
# Double checking for nulls
# rte_id            0
# distance          0
# elevation_gain    0
# elevation_loss    0
# avg_slope         0
# avg_speed         0
# max_speed         0
# duration          0
# moving_time       0
# dtype: int64
#
#
# 19571 unique trips
#      rte_id  distance  elevation_gain  elevation_loss  avg_slope  avg_speed  \
# 0  23209396  2.659848      123.437454      106.163973   1.634872   5.002846
# 1  54372107  2.762263      142.176885      172.413597   2.156983   5.171163
# 2  48496079  2.777424      480.997881      393.434553   5.962798   5.518063
# 3  40433541  2.779512       57.147474       41.855717   0.674601   5.192650
# 4  56203693  2.801186       97.503446       88.391781   1.256876   5.349746
#
#    max_speed  duration  moving_time
# 0   7.048852  0.619444     0.531667
# 1   5.960829  0.540556     0.534167
# 2  11.760722  0.535278     0.503333
# 3   5.432662  0.580000     0.535278
# 4   6.874868  0.568611     0.523611

# %% [markdown]
# For any trips that make it through the filter, request more detailed information from the API.

# %%
print('Requesting data for each trip')
trips = pd.read_feather(
    os.path.join(config.CLEAN_DATA_PATH, 'ridewgps_trips.feather')
)
trips.set_index('rte_id', inplace=True)
for i, rte_id in enumerate(trips.index.tolist()):
    if not i % 100:
        print('{} of {} trips'.format(i, trips.shape[0]))
    get_data.ridewithgps_api_ride(rte_id, 'trips')
#     time.sleep(0.05)
# Out:
# Requesting data for each trip
# 0 of 19571 trips
# 100 of 19571 trips
# 200 of 19571 trips
# 300 of 19571 trips
# 400 of 19571 trips
# 500 of 19571 trips
# 600 of 19571 trips
# 700 of 19571 trips
# 800 of 19571 trips
# 900 of 19571 trips
# 1000 of 19571 trips
# 1100 of 19571 trips
# 1200 of 19571 trips
# 1300 of 19571 trips
# 1400 of 19571 trips
# 1500 of 19571 trips
# 1600 of 19571 trips
# 1700 of 19571 trips
# 1800 of 19571 trips
# 1900 of 19571 trips
# 2000 of 19571 trips
# 2100 of 19571 trips
# 2200 of 19571 trips
# 2300 of 19571 trips
# 2400 of 19571 trips
# 2500 of 19571 trips
# 2600 of 19571 trips
# 2700 of 19571 trips
# 2800 of 19571 trips
# 2900 of 19571 trips
# 3000 of 19571 trips
# 3100 of 19571 trips
# 3200 of 19571 trips
# 3300 of 19571 trips
# 3400 of 19571 trips
# 3500 of 19571 trips
# 3600 of 19571 trips
# 3700 of 19571 trips
# 3800 of 19571 trips
# 3900 of 19571 trips
# 4000 of 19571 trips
# 4100 of 19571 trips
# 4200 of 19571 trips
# 4300 of 19571 trips
# 4400 of 19571 trips
# 4500 of 19571 trips
# 4600 of 19571 trips
# 4700 of 19571 trips
# 4800 of 19571 trips
# 4900 of 19571 trips
# 5000 of 19571 trips
# 5100 of 19571 trips
# 5200 of 19571 trips
# 5300 of 19571 trips
# 5400 of 19571 trips
# 5500 of 19571 trips
# 5600 of 19571 trips
# 5700 of 19571 trips
# 5800 of 19571 trips
# 5900 of 19571 trips
# 6000 of 19571 trips
# 6100 of 19571 trips
# 6200 of 19571 trips
# 6300 of 19571 trips
# 6400 of 19571 trips
# 6500 of 19571 trips
# 6600 of 19571 trips
# 6700 of 19571 trips
# 6800 of 19571 trips
# 6900 of 19571 trips
# 7000 of 19571 trips
# 7100 of 19571 trips
# 7200 of 19571 trips
# 7300 of 19571 trips
# 7400 of 19571 trips
# 7500 of 19571 trips
# 7600 of 19571 trips
# 7700 of 19571 trips
# 7800 of 19571 trips
# 7900 of 19571 trips
# 8000 of 19571 trips
# 8100 of 19571 trips
# 8200 of 19571 trips
# 8300 of 19571 trips
# 8400 of 19571 trips
# 8500 of 19571 trips
# 8600 of 19571 trips
# 8700 of 19571 trips
# 8800 of 19571 trips
# 8900 of 19571 trips
# 9000 of 19571 trips
# 9100 of 19571 trips
# 9200 of 19571 trips
# 9300 of 19571 trips
# 9400 of 19571 trips
# 9500 of 19571 trips
# 9600 of 19571 trips
# 9700 of 19571 trips
# 9800 of 19571 trips
# 9900 of 19571 trips
# 10000 of 19571 trips
# 10100 of 19571 trips
# 10200 of 19571 trips
# 10300 of 19571 trips
# 10400 of 19571 trips
# 10500 of 19571 trips
# 10600 of 19571 trips
# 10700 of 19571 trips
# 10800 of 19571 trips
# 10900 of 19571 trips
# 11000 of 19571 trips
# 11100 of 19571 trips
# 11200 of 19571 trips
# 11300 of 19571 trips
# 11400 of 19571 trips
# 11500 of 19571 trips
# 11600 of 19571 trips
# 11700 of 19571 trips
# 11800 of 19571 trips
# 11900 of 19571 trips
# 12000 of 19571 trips
# 12100 of 19571 trips
# 12200 of 19571 trips
# 12300 of 19571 trips
# 12400 of 19571 trips
# 12500 of 19571 trips
# 12600 of 19571 trips
# 12700 of 19571 trips
# 12800 of 19571 trips
# 12900 of 19571 trips
# 13000 of 19571 trips
# 13100 of 19571 trips
# 13200 of 19571 trips
# 13300 of 19571 trips
# 13400 of 19571 trips
# 13500 of 19571 trips
# 13600 of 19571 trips
# 13700 of 19571 trips
# 13800 of 19571 trips
# 13900 of 19571 trips
# 14000 of 19571 trips
# 14100 of 19571 trips
# 14200 of 19571 trips
# 14300 of 19571 trips
# 14400 of 19571 trips
# 14500 of 19571 trips
# 14600 of 19571 trips
# 14700 of 19571 trips
# 14800 of 19571 trips
# 14900 of 19571 trips
# 15000 of 19571 trips
# 15100 of 19571 trips
# 15200 of 19571 trips
# 15300 of 19571 trips
# 15400 of 19571 trips
# 15500 of 19571 trips
# 15600 of 19571 trips
# 15700 of 19571 trips
# 15800 of 19571 trips
# 15900 of 19571 trips
# 16000 of 19571 trips
# 16100 of 19571 trips
# 16200 of 19571 trips
# 16300 of 19571 trips
# 16400 of 19571 trips
# 16500 of 19571 trips
# 16600 of 19571 trips
# 16700 of 19571 trips
# 16800 of 19571 trips
# 16900 of 19571 trips
# 17000 of 19571 trips
# 17100 of 19571 trips
# 17200 of 19571 trips
# 17300 of 19571 trips
# 17400 of 19571 trips
# 17500 of 19571 trips
# 17600 of 19571 trips
# 17700 of 19571 trips
# 17800 of 19571 trips
# 17900 of 19571 trips
# 18000 of 19571 trips
# 18100 of 19571 trips
# 18200 of 19571 trips
# 18300 of 19571 trips
# 18400 of 19571 trips
# 18500 of 19571 trips
# 18600 of 19571 trips
# 18700 of 19571 trips
# 18800 of 19571 trips
# 18900 of 19571 trips
# 19000 of 19571 trips
# 19100 of 19571 trips
# 19200 of 19571 trips
# 19300 of 19571 trips
# 19400 of 19571 trips
# 19500 of 19571 trips

# %% [markdown]
# ### Clean each individual trip
#
# Cleaning steps:
#
# - Rename the columns to have clearer names, e.g. 'y' -> 'lon'
# - Drop nulls
# - Calculate distances between lat/lon breadcrumbs
# - Set time to be in hours, with 0 at the start of the ride
# - Calculate slope and speed at every point, and smooth these values

# %%
trips = pd.read_feather(
    os.path.join(config.CLEAN_DATA_PATH, 'ridewgps_trips.feather')
)
trips.set_index('rte_id', inplace=True)

print('Cleaning individual trips')
for i, rte_id in enumerate(trips.index.tolist()):
    if not i % 100:
        print('{} of {} trips'.format(i, trips.shape[0]))
    if os.path.exists(
        os.path.join(config.CLEAN_TRIPS_PATH, '{}.feather'.format(rte_id))
        ):
        continue
        
        
    rte = pd.read_feather(
        os.path.join(config.RAW_TRIPS_PATH, '{}.feather'.format(rte_id))
    )
    rte_clean = clean_data.clean_single_trip(rte)
    if rte_clean.empty:
        continue
    
    pathlib.Path(config.CLEAN_TRIPS_PATH).mkdir(parents=True, exist_ok=True)
    rte_clean.to_feather(
       os.path.join(config.CLEAN_TRIPS_PATH, '{}.feather'.format(rte_id)) 
    )
# Out:
# Cleaning individual trips
# 0 of 19571 trips
# 100 of 19571 trips
# 200 of 19571 trips
# 300 of 19571 trips
# 400 of 19571 trips
# 500 of 19571 trips
# 600 of 19571 trips
# 700 of 19571 trips
# 800 of 19571 trips
# 900 of 19571 trips
# 1000 of 19571 trips
# 1100 of 19571 trips
# 1200 of 19571 trips
# 1300 of 19571 trips
# 1400 of 19571 trips
# 1500 of 19571 trips
# 1600 of 19571 trips
# 1700 of 19571 trips
# 1800 of 19571 trips
# 1900 of 19571 trips
# 2000 of 19571 trips
# 2100 of 19571 trips
# 2200 of 19571 trips
# 2300 of 19571 trips
# 2400 of 19571 trips
# 2500 of 19571 trips
# 2600 of 19571 trips
# 2700 of 19571 trips
# 2800 of 19571 trips
# 2900 of 19571 trips
# 3000 of 19571 trips
# 3100 of 19571 trips
# 3200 of 19571 trips
# 3300 of 19571 trips
# 3400 of 19571 trips
# 3500 of 19571 trips
# 3600 of 19571 trips
# 3700 of 19571 trips
# 3800 of 19571 trips
# 3900 of 19571 trips
# 4000 of 19571 trips
# 4100 of 19571 trips
# 4200 of 19571 trips
# 4300 of 19571 trips
# 4400 of 19571 trips
# 4500 of 19571 trips
# 4600 of 19571 trips
# 4700 of 19571 trips
# 4800 of 19571 trips
# 4900 of 19571 trips
# 5000 of 19571 trips
# 5100 of 19571 trips
# 5200 of 19571 trips
# 5300 of 19571 trips
# 5400 of 19571 trips
# 5500 of 19571 trips
# 5600 of 19571 trips
# 5700 of 19571 trips
# 5800 of 19571 trips
# 5900 of 19571 trips
# 6000 of 19571 trips
# 6100 of 19571 trips
# 6200 of 19571 trips
# 6300 of 19571 trips
# 6400 of 19571 trips
# 6500 of 19571 trips
# 6600 of 19571 trips
# 6700 of 19571 trips
# 6800 of 19571 trips
# 6900 of 19571 trips
# 7000 of 19571 trips
# 7100 of 19571 trips
# 7200 of 19571 trips
# 7300 of 19571 trips
# 7400 of 19571 trips
# 7500 of 19571 trips
# 7600 of 19571 trips
# 7700 of 19571 trips
# 7800 of 19571 trips
# 7900 of 19571 trips
# 8000 of 19571 trips
# 8100 of 19571 trips
# 8200 of 19571 trips
# 8300 of 19571 trips
# 8400 of 19571 trips
# 8500 of 19571 trips
# 8600 of 19571 trips
# 8700 of 19571 trips
# 8800 of 19571 trips
# 8900 of 19571 trips
# 9000 of 19571 trips
# 9100 of 19571 trips
# 9200 of 19571 trips
# 9300 of 19571 trips
# 9400 of 19571 trips
# 9500 of 19571 trips
# 9600 of 19571 trips
# 9700 of 19571 trips
# 9800 of 19571 trips
# 9900 of 19571 trips
# 10000 of 19571 trips
# 10100 of 19571 trips
# 10200 of 19571 trips
# 10300 of 19571 trips
# 10400 of 19571 trips
# 10500 of 19571 trips
# 10600 of 19571 trips
# 10700 of 19571 trips
# 10800 of 19571 trips
# 10900 of 19571 trips
# 11000 of 19571 trips
# 11100 of 19571 trips
# 11200 of 19571 trips
# 11300 of 19571 trips
# 11400 of 19571 trips
# 11500 of 19571 trips
# 11600 of 19571 trips
# 11700 of 19571 trips
# 11800 of 19571 trips
# 11900 of 19571 trips
# 12000 of 19571 trips
# 12100 of 19571 trips
# 12200 of 19571 trips
# 12300 of 19571 trips
# 12400 of 19571 trips
# 12500 of 19571 trips
# 12600 of 19571 trips
# 12700 of 19571 trips
# 12800 of 19571 trips
# 12900 of 19571 trips
# 13000 of 19571 trips
# 13100 of 19571 trips
# 13200 of 19571 trips
# 13300 of 19571 trips
# 13400 of 19571 trips
# 13500 of 19571 trips
# 13600 of 19571 trips
# 13700 of 19571 trips
# 13800 of 19571 trips
# 13900 of 19571 trips
# 14000 of 19571 trips
# 14100 of 19571 trips
# 14200 of 19571 trips
# 14300 of 19571 trips
# 14400 of 19571 trips
# 14500 of 19571 trips
# 14600 of 19571 trips
# 14700 of 19571 trips
# 14800 of 19571 trips
# 14900 of 19571 trips
# 15000 of 19571 trips
# 15100 of 19571 trips
# 15200 of 19571 trips
# 15300 of 19571 trips
# 15400 of 19571 trips
# 15500 of 19571 trips
# 15600 of 19571 trips
# 15700 of 19571 trips
# 15800 of 19571 trips
# 15900 of 19571 trips
# 16000 of 19571 trips
# 16100 of 19571 trips
# 16200 of 19571 trips
# 16300 of 19571 trips
# 16400 of 19571 trips
# 16500 of 19571 trips
# 16600 of 19571 trips
# 16700 of 19571 trips
# 16800 of 19571 trips
# 16900 of 19571 trips
# 17000 of 19571 trips
# 17100 of 19571 trips
# 17200 of 19571 trips
# 17300 of 19571 trips
# 17400 of 19571 trips
# 17500 of 19571 trips
# 17600 of 19571 trips
# 17700 of 19571 trips
# 17800 of 19571 trips
# 17900 of 19571 trips
# 18000 of 19571 trips
# 18100 of 19571 trips
# 18200 of 19571 trips
# 18300 of 19571 trips
# 18400 of 19571 trips
# 18500 of 19571 trips
# 18600 of 19571 trips
# 18700 of 19571 trips
# 18800 of 19571 trips
# 18900 of 19571 trips
# 19000 of 19571 trips
# 19100 of 19571 trips
# 19200 of 19571 trips
# 19300 of 19571 trips
# 19400 of 19571 trips
# 19500 of 19571 trips

# %% [markdown]
# Finally, remove any trips from the overall database that we couldn't download the breadcrumb level data for.

# %%
trips = pd.read_feather(
    os.path.join(config.CLEAN_DATA_PATH, 'ridewgps_trips.feather')
)
# List all [rte_id].feather files in CLEAN_TRIPS_PATH
clean_trip_ids = [rte_id.stem for rte_id 
                  in pathlib.Path(config.CLEAN_TRIPS_PATH).glob('*.feather')]


trips = trips[(trips['rte_id'].isin(clean_trip_ids))].reset_index(drop=True)

# Save this to PROCESSED_DATA_PATH as the trips DataFrame for use in all other code
pathlib.Path(config.PROCESSED_DATA_PATH).mkdir(parents=True, exist_ok=True)
trips.to_feather(
    os.path.join(config.PROCESSED_DATA_PATH, 'trips.feather')
)
print(trips.shape)
# Out:
# (19570, 9)
